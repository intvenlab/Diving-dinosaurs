# %%
include("misc_3class.jl")
using .RunOrAnalyze

# %% [markdown]
# ### Launch a full-suit run  (This is the 3-class version of run_or_analyze.ipynb!!!)
# Given a data file perform
# * single (which means just simple prediction of test taxa labels)
# * loocv (leave one out cross validation in which we just take the training part of the data and iteratively treat one of its members as test taxa to predict its value. At the end we will have a cross-validation of oor code's predictive power.)
# * kfoldcv (k-fold cross validation, in which we just take the training part of the data and divide the shuffled set to K partitions. Iteratively we treat one of the partitions as test set and predict it using training by taking the rest). If wanted we can make more than one such cross-validations to improve statistics.
# * bootstrap (in order to have a measure of variance for our predictions, we repeatedly make predictions for test taxa using training sets that are varied according to the bootrap procedure, in which we keep the number of training set the same but the make up of each training set is obtained by resampling the original training set with replacement)

# %%
# full analysis means performing single (binary_classification), loocv, k-fold cv, and bootstrap

# explanation for addTreeTips: TRUE if either holds: 
#                              a) user added a test taxon as a variant of an existing taxon 
#                              b) any bootstrap run. 

# Always use the data directory for data file location. Easier to keep track of stuff. 


homeDir = "C:/Users/cozen/dino_nature/output/D9_10_28_2022"    # where full analysis folders are (or will be) placed at

boneType            = "femur"                                                                # enter "femur" or "ribs" 
dataFile            = "C:/Users/cozen/dino_nature/data/D9_femur.csv"                         # bone data file (with path). See above.
applyDataFilter     = "FALSE"                                                                # enter FALSE (no filter) or filter name. (see auxiliary.r) 
addTreeTips         = "TRUE"                                                                 # see explanations
Ntrees              = 100                                                                    # no of random trees to be generated
calculateTrees      = "TRUE"                                                                 # calculate (TRUE) or read (FALSE) trees
saveTrees           = "FALSE"                                                                # save (TRUE) trees (if they are calculated here)
Kcrossvalidation    = 10                                                                     # # of data partitions (K) in a K-fold CV 
Nkfoldcv            = 10                                                                     # how many rounds of k-fold cv is wanted   
Nbootstrapsets      = 2000                                                                   # # of bootstrap sets

newfullsuitrun(homeDir, boneType, dataFile, applyDataFilter, addTreeTips, Ntrees, calculateTrees,saveTrees,Kcrossvalidation,Nkfoldcv,Nbootstrapsets)
# Out:
# [1] "* Regression data contains multiple copies of some taxa (user added variants of existing test taxa \n   or replacements due to bootstrap are present) which are not in the phylo tree:"
#       bases          duplicates
#  [1,] "Spinosaurus_" "Spinosaurus_.1"
#  [2,] "Spinosaurus_" "Spinosaurus_.2"
#  [3,] "Spinosaurus_" "Spinosaurus_.3"
#  [4,] "Spinosaurus_" "Spinosaurus_.4"
#  [5,] "Spinosaurus_" "Spinosaurus_.5"
#  [6,] "Spinosaurus_" "Spinosaurus_.6"
#  [7,]
# ┌ Warning: RCall.jl: Loading required package: RRPP
# │ Loading required package: rgl
# │ Loading required package: Matrix
# │ Loading required package: maps
# │ Keep up to date with changes at https://www.tidyverse.org/blog/
# │
# │ Attaching package: 'svgViewR'
# │
# │ The following objects are masked from 'package:rgl':
# │
# │     readOBJ, writeOBJ
# │
# │        --- dispRity package ---
# │ This is the CRAN release version (1.7.0) of the package.
# │ For news, vignettes and future releases,
# │ visit https://github.com/TGuillerme/dispRity
# │
# │
# │ Attaching package: 'dispRity'
# │
# │ The following object is masked from 'package:geomorph':
# │
# │     combine.subsets
# │
# │ The following object is masked from 'package:RRPP':
# │
# │     add.tree
# │
# │
# │ Attaching package: 'MASS'
# │
# │ The following object is masked from 'package:formattable':
# │
# │     area
# │
# │ Loading required package: mda
# │ Loading required package: class
# │ Loaded mda 0.5-3
# │
# │ Loading required package: nlme
# │ Loading required package: qpcR
# │ Loading required package: minpack.lm
# │ Loading required package: robustbase
# │ Loading required package: klaR
# │ Registered S3 methods overwritten by 'klaR':
# │   method      from
# │   predict.rda vegan
# │   print.rda   vegan
# │   plot.rda    vegan
# │
# │ Attaching package: 'dplyr'
# │
# │ The following object is masked from 'package:nlme':
# │
# │     collapse
# │
# │ The following object is masked from 'package:MASS':
# │
# │     select
# │
# │ The following objects are masked from 'package:stats':
# │
# │     filter, lag
# │
# │ The following objects are masked from 'package:base':
# │
# │     intersect, setdiff, setequal, union
# │
# │ Loading required package: sjmisc
# │ data.table 1.14.2 using 8 threads (see ?getDTthreads).  Latest news: r-datatable.com
# │
# │ Attaching package: 'data.table'
# │
# │ The following objects are masked from 'package:dplyr':
# │
# │     between, first, last
# │
# └ @ RCall C:\Users\cozen\.julia\packages\RCall\6kphM\src\io.jl:172
#  "Spinosaurus_" "Spinosaurus_.7"
#  [8,] "Spinosaurus_" "Spinosaurus_.8"
#  [9,] "Spinosaurus_" "Spinosaurus_.9"
# [10,] "Spinosaurus_" "Spinosaurus_.10"
# [11,] "Spinosaurus_" "Spinosaurus_.11"
# [12,] "Suchomimus"   "Suchomimus.1"
# [13,] "Suchomimus"   "Suchomimus.2"
# [14,] "Suchomimus"   "Suchomimus.3"
# [15,] "Baryonyx"     "Baryonyx.1"
# [16,] "Baryonyx"     "Baryonyx.2"
# [17,] "Baryonyx"
#  "Baryonyx.3"
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"
#  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
#  [1] "Spinosaurus_.11" "Spinosaurus_.10" "Spinosaurus_.9"  "Spinosaurus_.8"
#  [5] "Spinosaurus_.7"  "Spinosaurus_.6"  "Spinosaurus_.5"  "Spinosaurus_.4"
#  [9] "Spinosaurus_.3"  "Spinosaurus_.2"  "Spinosaurus_.1"  "Spinosaurus_"
# [13] NA
# [1] "Baryonyx.3"   "Baryonyx.2"   "Baryonyx.1"   "Suchomimus.3" "Suchomimus.2"
# [6] "Suchomimus.1" "Suchomimus"   "Baryonyx"
# [1] "Baryonyx.3"   "Baryonyx.2"   "Baryonyx.1"   "Suchomimus.3" "Suchomimus.2"
# [6] "Suchomimus.1" "Suchomimus"   "Baryonyx"
# [1] "Baryonyx.3"   "Baryonyx.2"   "Baryonyx.1"   "Suchomimus.3" "Suchomimus.2"
# [6] "Suchomimus.1" "Suchomimus"   "Baryonyx"
# [1] "Baryonyx.3"   "Baryonyx.2"   "Baryonyx.1"   "Suchomimus.3" "Suchomimus.2"
# [6] "Suchomimus.1" "Suchomimus"   "Baryonyx"
# [1] "Baryonyx.3"   "Baryonyx.2"   "Baryonyx.1"   "Suchomimus.3" "Suchomimus.2"
# [6] "Suchomimus.1" "Suchomimus"   "Baryonyx"
# [1] "Baryonyx.3"   "Baryonyx.2"   "Baryonyx.1"   "Suchomimus.3" "Suchomimus.2"
# [6] "Suchomimus.1" "Suchomimus"   "Baryonyx"
# [1] "* Phylo tree and the main data and strata files have been modified to include duplicated taxa before the scaled random trees are generated."
# [1] "* Selected categorical labels column: diving.or.not"
# [1] "* diving.or.equal column is identical to Diving column."
# [1] "* Regression includes flying taxa."
# [1] "* Diving labels that are present in regression: 0,1,2"
# [1] "The following taxa are in the tree but not in the data. Hence we remove them from the tree:"
#  [1] "Alamosaurus"             "Alca_torda"
#  [3] "Allosaurus_"             "Anas_aucklandica"
#  [5] "Anas_discors"            "Anas_erythroincha"
#  [7] "Anhinga_anhinga"         "Anser_fabalis"
#  [9] "Anseranas_semipalmata"   "Antetonitrus"
# [11] "Aramus_guarauna"         "Asfaltovenator"
# [13] "Asilisaurus"             "Australovenator"
# [15] "Avimaia"                 "Cinclus_cinclus"
# [17] "Condorraptor"            "Cygnus_olor"
# [19] "Deinonychus"             "Dysalotosaurus"
# [21] "Eustreptospondylus"      "Fratercula_arctica"
# [23] "Fruitadens"              "Gallimimus_sp"
# [25] "Gallus_domesticus"       "Gavia_immer"
# [27] "Gobiraptor_"             "Gorgosaurus"
# [29] "Halszkararaptor_"        "Iberosuchus"
# [31] "Iteravis"                "Lepidus"
# [33] "Masiakasaurus"           "Megalosaurus"
# [35] "Mirusavis"               "Mussaurus"
# [37] "noasaurid_kem_kem"       "Oviraptor_"
# [39] "Oviraptor_caenagnathid"  "Oxyura_jamaicensis"
# [41] "Pelagodroma_marina"      "Pelecanoides_urinatryx"
# [43] "Phaeton_aethereus"       "Phalacrocorax_carbo"
# [45] "Phoenicopterus_roseus"   "Plateosaurus"
# [47] "Podica_senegalensis"     "Poposaurus"
# [49] "Porphyrio_Poliocephalus" "Porzana_carolina"
# [51] "Rahonavis"               "Rativates"
# [53] "Scutellosaurus_lawleri"  "Stegosaurus_sp"
# [55] "Sula"                    "Syntarsus_"
# [57] "Tachybaptus"             "Tenontosaurus"
# [59] "Torvosaurus"             "Troodon_formosus"
# [61] "Tyrannosaurus"           "Tyrannotitan"
# [63] "Unamed_theropod_kem_kem" "Uria"
# [65] "Ursus_maritimus"         "Vegavis"
# [1] "The following taxa are in the data but not in the tree. Hence we remove them from the data:"
# [1] "Rhinoceros_unicornis"
# [1] 0.04
# [1] "* index-name alignment check: OK"
# REvalError: Loading required package: nnet
#
# Loading required package: lattice
#
# Warning: Following taxa dropped from timeList: Rhinoceros_unicornis
#
# Error in mindist[l] <- ndist[l] :
#
#   NAs are not allowed in subscripted assignments
#
#
#
# Stacktrace:
#
#  [1] handle_eval_stderr(; as_warning::Bool)
#
#    @ RCall C:\Users\cozen\.julia\packages\RCall\6kphM\src\io.jl:174
#
#  [2] reval_p(expr::Ptr{RCall.LangSxp}, env::Ptr{RCall.EnvSxp})
#
#    @ RCall C:\Users\cozen\.julia\packages\RCall\6kphM\src\eval.jl:103
#
#  [3] reval_p(expr::Ptr{RCall.ExprSxp}, env::Ptr{RCall.EnvSxp})
#
#    @ RCall C:\Users\cozen\.julia\packages\RCall\6kphM\src\eval.jl:119
#
#  [4] reval(str::String, env::RCall.RObject{RCall.EnvSxp})
#
#    @ RCall C:\Users\cozen\.julia\packages\RCall\6kphM\src\eval.jl:136
#
#  [5] macro expansion
#
#    @ C:\Users\cozen\.julia\packages\RCall\6kphM\src\macros.jl:71 [inlined]
#
#  [6] single(homeDir::String, boneType::String, dataFile::String, applyDataFilter::String, addTreeTips::String, Ntrees::Int64, calculateTrees::String, saveTrees::String)
#
#    @ Main.RunOrAnalyze c:\Users\cozen\dino_nature\code\misc_3class.jl:50
#
#  [7] newfullsuitrun(homeDir::String, boneType::String, dataFile::String, applyDataFilter::String, addTreeTips::String, Ntrees::Int64, calculateTrees::String, saveTrees::String, Kcrossvalidation::Int64, Nkfoldcv::Int64, Nbootstrapsets::Int64)
#
#    @ Main.RunOrAnalyze c:\Users\cozen\dino_nature\code\misc_3class.jl:115
#
#  [8] top-level scope
#
#    @ c:\Users\cozen\dino_nature\code\run_or_analyze_3class.ipynb:23

# %% [markdown]
# ### Analyze a Full-suit Run

# %%
homeDir = "C:/Users/cozen/dino_nature/output/D9_10_28_2022"
Nkfoldcv = 10
fullsuitpostprocess(homeDir, Nkfoldcv)
# Out:
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_10\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_100\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1000\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1001\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1002\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1003\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1004\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1005\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1006\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1007\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1008\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1009\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_101\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1010\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1011\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1012\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1013\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1014\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1015\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1016\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1017\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1018\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1019\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_102\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1020\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1021\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1022\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1023\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1024\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1025\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1026\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1027\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1028\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1029\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_103\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1030\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1031\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1032\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1033\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1034\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1035\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1036\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1037\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1038\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1039\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_104\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1040\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1041\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1042\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1043\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1044\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1045\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1046\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1047\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1048\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1049\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_105\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1050\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1051\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1052\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1053\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1054\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1055\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1056\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1057\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1058\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1059\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_106\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1060\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1061\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1062\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1063\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1064\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1065\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1066\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1067\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1068\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1069\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_107\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1070\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1071\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1072\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1073\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1074\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1075\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1076\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1077\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1078\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1079\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_108\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1080\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1081\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1082\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1083\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1084\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1085\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1086\PROBABILITIES.csvdoes not exist! Skipping!
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1087\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1088\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1089\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_109\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1090\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1091\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1092\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1093\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1094\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1095\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1096\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1097\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1098\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1099\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_11\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_110\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1100\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1101\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1102\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1103\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1104\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1105\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1106\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1107\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1108\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1109\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_111\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1110\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1111\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1112\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1113\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1114\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1115\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1116\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1117\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1118\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1119\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_112\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1120\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1121\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1122\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1123\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1124\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1125\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1126\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1127\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1128\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1129\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_113\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1130\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1131\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1132\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1133\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1134\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1135\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1136\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1137\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1138\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1139\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_114\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1140\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1141\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1142\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1143\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1144\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1145\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1146\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1147\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1148\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1149\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_115\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1150\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1151\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1152\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1153\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1154\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1155\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1156\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1157\PROBABILITIES.csvdoes not exist! Skipping!
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1158\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1159\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_116\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1160\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1161\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1162\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1163\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1164\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1165\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1166\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1167\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1168\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1169\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_117\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1170\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1171\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1172\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1173\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1174\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1175\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1176\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1177\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1178\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1179\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_118\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1180\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1181\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1182\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1183\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1184\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1185\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1186\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1187\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1188\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1189\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_119\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1190\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1191\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1192\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1193\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1194\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1195\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1196\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1197\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1198\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1199\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_12\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_120\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1200\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1201\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1202\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1203\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1204\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1205\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1206\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1207\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1208\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1209\PROBABILITIES.csvdoes not exist! Skipping!
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_121\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1210\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1211\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1212\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1213\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1214\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1215\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1216\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1217\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1218\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1219\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_122\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1220\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1221\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1222\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1223\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1224\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1225\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1226\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1227\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1228\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1229\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_123\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1230\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1231\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1232\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1233\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1234\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1235\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1236\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1237\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1238\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1239\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_124\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1240\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1241\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1242\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1243\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1244\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1245\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1246\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1247\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1248\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1249\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_125\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1250\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1251\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1252\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1253\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1254\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1255\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1256\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1257\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1258\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1259\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_126\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1260\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1261\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1262\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1263\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1264\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1265\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1266\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1267\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1268\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1269\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_127\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1270\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1271\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1272\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1273\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1274\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1275\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1276\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1277\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1278\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1279\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_128\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1280\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1281\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1282\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1283\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1284\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1285\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1286\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1287\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1288\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1289\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_129\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1290\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1291\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1292\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1293\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1294\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1295\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1296\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1297\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1298\PROBABILITIES.csvdoes not exist! Skipping!
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1299\PROBABILITIES.csvdoes not exist! Skipping!
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_13\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_130\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1300\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1301\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1302\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1303\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1304\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1305\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1306\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1307\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1308\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1309\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_131\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1310\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1311\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1312\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1313\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1314\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1315\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1316\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1317\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1318\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1319\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_132\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1320\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1321\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1322\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1323\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1324\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1325\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1326\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1327\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1328\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1329\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_133\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1330\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1331\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1332\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1333\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1334\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1335\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1336\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1337\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1338\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1339\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_134\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1340\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1341\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1342\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1343\PROBABILITIES.csvdoes not exist! Skipping!
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1344\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1345\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1346\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1347\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1348\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1349\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_135\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1350\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1351\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1352\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1353\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1354\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1355\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1356\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1357\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1358\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1359\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_136\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1360\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1361\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1362\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1363\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1364\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1365\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1366\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1367\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1368\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1369\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_137\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1370\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1371\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1372\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1373\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1374\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1375\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1376\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1377\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1378\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1379\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_138\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1380\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1381\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1382\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1383\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1384\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1385\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1386\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1387\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1388\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1389\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_139\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1390\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1391\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1392\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1393\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1394\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1395\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1396\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1397\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1398\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1399\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_14\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_140\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1400\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1401\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1402\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1403\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1404\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1405\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1406\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1407\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1408\PROBABILITIES.csvdoes not exist! Skipping!
#
# C:/Users/cozen/dino_nature/output/D11_10_24_2022\bs\set_1409\PROBABILITIES.csvdoes not exist! Skipping!
#
# ...
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
# Excessive output truncated after 524289 bytes.
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
#
# Either probability or confusion matrix is missing! Skipping a set!
# "C:/Users/cozen/dino_nature/output/D11_10_24_2022\\analysis\\bsPCM.csv"

# %% [markdown]
# ### Run a session for any of "single" or "loocv" or "kfoldcv" or "bs" runs

# %% [markdown]
# ### Compress the output of only one directory containing either "single" or "loocv" or "kfoldcv" or "bs" runs.

# %%
runType = "kfoldcv"     # Enter one of: "single", "loocv", "kfoldcv", "bs"
baseDir = "/home/cem/Desktop/dino_nature/output/test_kfoldcv"
compressor(runType, baseDir)
# Out:
# 294
